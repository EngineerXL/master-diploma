# %%
from src.dataset.postprocess import PostprocessingWrapper, ttest_related_ride_metrics

# %%
ttest_related_ride_metrics(
    "/workspaces/master-diploma/scripts/resources/big_pipeline_20_sec.json",
    "/workspaces/master-diploma/scripts/resources/big_pipeline_20_sec_kalman.json",
    alternative="greater",
)
# Out:
# <style type="text/css">
# #T_0dbcf_row2_col0, #T_0dbcf_row2_col1, #T_0dbcf_row2_col2, #T_0dbcf_row2_col3, #T_0dbcf_row2_col4, #T_0dbcf_row5_col0, #T_0dbcf_row8_col0, #T_0dbcf_row11_col0, #T_0dbcf_row11_col1, #T_0dbcf_row11_col2, #T_0dbcf_row11_col3, #T_0dbcf_row11_col4, #T_0dbcf_row14_col0, #T_0dbcf_row14_col1, #T_0dbcf_row14_col2, #T_0dbcf_row14_col3, #T_0dbcf_row14_col4, #T_0dbcf_row17_col4 {
#   background-color: black;
# }
# #T_0dbcf_row5_col1, #T_0dbcf_row5_col2, #T_0dbcf_row5_col3, #T_0dbcf_row5_col4, #T_0dbcf_row8_col1, #T_0dbcf_row8_col2, #T_0dbcf_row8_col3, #T_0dbcf_row8_col4, #T_0dbcf_row17_col0, #T_0dbcf_row17_col1, #T_0dbcf_row17_col2, #T_0dbcf_row17_col3 {
#   background-color: black;
#   color: green;
# }
# </style>
# <table id="T_0dbcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0dbcf_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_0dbcf_level0_col1" class="col_heading level0 col1" >std</th>
# ...
