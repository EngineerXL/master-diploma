# %%
from src.dataset.postprocess import ttest_related_ride_metrics

# %%
ttest_related_ride_metrics(
    "/workspaces/master-diploma/scripts/resources/boreas_rt_benchmark_10_sec_truck_overtake.json",
    "/workspaces/master-diploma/scripts/resources/boreas_rt_benchmark_10_sec_truck_overtake_kalman.json",
    alternative="greater",
)
# Out:
# <style type="text/css">
# #T_9037d_row4_col0 {
#   background-color: black;
#   color: red;
# }
# #T_9037d_row4_col1, #T_9037d_row4_col2, #T_9037d_row4_col3, #T_9037d_row4_col4, #T_9037d_row4_col5, #T_9037d_row9_col1, #T_9037d_row9_col2, #T_9037d_row9_col3, #T_9037d_row9_col4, #T_9037d_row9_col5, #T_9037d_row14_col1, #T_9037d_row14_col2, #T_9037d_row14_col3, #T_9037d_row14_col4, #T_9037d_row14_col5, #T_9037d_row19_col4, #T_9037d_row29_col1, #T_9037d_row29_col2, #T_9037d_row29_col3, #T_9037d_row29_col4, #T_9037d_row29_col5 {
#   background-color: black;
#   color: green;
# }
# #T_9037d_row9_col0, #T_9037d_row14_col0, #T_9037d_row19_col0, #T_9037d_row19_col1, #T_9037d_row19_col2, #T_9037d_row19_col3, #T_9037d_row19_col5, #T_9037d_row24_col0, #T_9037d_row24_col1, #T_9037d_row24_col2, #T_9037d_row24_col3, #T_9037d_row24_col4, #T_9037d_row24_col5, #T_9037d_row29_col0 {
#   background-color: black;
# }
# </style>
# <table id="T_9037d">
#   <thead>
#     <tr>
# ...

# %%
ttest_related_ride_metrics(
    "/workspaces/master-diploma/scripts/resources/big_pipeline_20_sec.json",
    "/workspaces/master-diploma/scripts/resources/big_pipeline_20_sec_kalman.json",
    alternative="greater",
)
# Out:
# <style type="text/css">
# #T_232f5_row4_col0, #T_232f5_row4_col1, #T_232f5_row4_col2, #T_232f5_row4_col3, #T_232f5_row4_col4, #T_232f5_row4_col5, #T_232f5_row9_col0, #T_232f5_row14_col0, #T_232f5_row19_col0, #T_232f5_row19_col1, #T_232f5_row19_col2, #T_232f5_row19_col3, #T_232f5_row19_col4, #T_232f5_row19_col5, #T_232f5_row24_col0, #T_232f5_row24_col1, #T_232f5_row24_col2, #T_232f5_row24_col3, #T_232f5_row24_col4, #T_232f5_row24_col5, #T_232f5_row29_col4 {
#   background-color: black;
# }
# #T_232f5_row9_col1, #T_232f5_row9_col2, #T_232f5_row9_col3, #T_232f5_row9_col4, #T_232f5_row9_col5, #T_232f5_row14_col1, #T_232f5_row14_col2, #T_232f5_row14_col3, #T_232f5_row14_col4, #T_232f5_row14_col5, #T_232f5_row29_col0, #T_232f5_row29_col1, #T_232f5_row29_col2, #T_232f5_row29_col3, #T_232f5_row29_col5 {
#   background-color: black;
#   color: green;
# }
# </style>
# <table id="T_232f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
ttest_related_ride_metrics(
    "/workspaces/master-diploma/scripts/resources/rt_benchmark_15_sec.json",
    "/workspaces/master-diploma/scripts/resources/rt_benchmark_15_sec_kalman.json",
    alternative="greater",
)
# Out:
# <style type="text/css">
# #T_6b846_row4_col0, #T_6b846_row4_col2, #T_6b846_row9_col0, #T_6b846_row14_col0, #T_6b846_row14_col4, #T_6b846_row19_col0, #T_6b846_row19_col1, #T_6b846_row19_col2, #T_6b846_row19_col3, #T_6b846_row19_col4, #T_6b846_row19_col5, #T_6b846_row24_col1, #T_6b846_row24_col2, #T_6b846_row24_col3, #T_6b846_row24_col4, #T_6b846_row24_col5, #T_6b846_row29_col0, #T_6b846_row29_col1, #T_6b846_row29_col2, #T_6b846_row29_col3, #T_6b846_row29_col4, #T_6b846_row29_col5 {
#   background-color: black;
# }
# #T_6b846_row4_col1, #T_6b846_row4_col3, #T_6b846_row4_col4, #T_6b846_row4_col5, #T_6b846_row9_col1, #T_6b846_row9_col2, #T_6b846_row9_col3, #T_6b846_row9_col4, #T_6b846_row9_col5, #T_6b846_row14_col1, #T_6b846_row14_col2, #T_6b846_row14_col3, #T_6b846_row14_col5 {
#   background-color: black;
#   color: green;
# }
# #T_6b846_row24_col0 {
#   background-color: black;
#   color: red;
# }
# </style>
# <table id="T_6b846">
#   <thead>
#     <tr>
# ...

# %%
ttest_related_ride_metrics(
    "/workspaces/master-diploma/scripts/resources/rt_benchmark_10_sec.json",
    "/workspaces/master-diploma/scripts/resources/rt_benchmark_10_sec_kalman.json",
    alternative="greater",
)
# Out:
# <style type="text/css">
# #T_58d79_row4_col0 {
#   background-color: black;
#   color: red;
# }
# #T_58d79_row4_col1, #T_58d79_row4_col2, #T_58d79_row4_col3, #T_58d79_row4_col4, #T_58d79_row4_col5, #T_58d79_row9_col1, #T_58d79_row9_col2, #T_58d79_row9_col3, #T_58d79_row9_col4, #T_58d79_row9_col5, #T_58d79_row14_col1, #T_58d79_row14_col2, #T_58d79_row14_col3, #T_58d79_row14_col4, #T_58d79_row14_col5, #T_58d79_row19_col4, #T_58d79_row29_col1, #T_58d79_row29_col2, #T_58d79_row29_col3, #T_58d79_row29_col4, #T_58d79_row29_col5 {
#   background-color: black;
#   color: green;
# }
# #T_58d79_row9_col0, #T_58d79_row14_col0, #T_58d79_row19_col0, #T_58d79_row19_col1, #T_58d79_row19_col2, #T_58d79_row19_col3, #T_58d79_row19_col5, #T_58d79_row24_col0, #T_58d79_row24_col1, #T_58d79_row24_col2, #T_58d79_row24_col3, #T_58d79_row24_col4, #T_58d79_row24_col5, #T_58d79_row29_col0 {
#   background-color: black;
# }
# </style>
# <table id="T_58d79">
#   <thead>
#     <tr>
# ...

# %%
ttest_related_ride_metrics(
    "/workspaces/master-diploma/scripts/resources/rt_benchmark_20_truck_offset.json",
    "/workspaces/master-diploma/scripts/resources/rt_benchmark_20_truck_offset_kalman.json",
    alternative="greater",
)
# Out:
# <style type="text/css">
# #T_6c321_row4_col0, #T_6c321_row4_col1, #T_6c321_row4_col2, #T_6c321_row4_col3, #T_6c321_row4_col4, #T_6c321_row4_col5, #T_6c321_row9_col0, #T_6c321_row14_col0, #T_6c321_row19_col0, #T_6c321_row19_col1, #T_6c321_row19_col2, #T_6c321_row19_col3, #T_6c321_row19_col4, #T_6c321_row19_col5, #T_6c321_row24_col0, #T_6c321_row24_col1, #T_6c321_row24_col2, #T_6c321_row24_col3, #T_6c321_row29_col0, #T_6c321_row29_col1, #T_6c321_row29_col2, #T_6c321_row29_col3, #T_6c321_row29_col4, #T_6c321_row29_col5 {
#   background-color: black;
# }
# #T_6c321_row9_col1, #T_6c321_row9_col2, #T_6c321_row9_col3, #T_6c321_row9_col4, #T_6c321_row9_col5, #T_6c321_row14_col1, #T_6c321_row14_col2, #T_6c321_row14_col3, #T_6c321_row14_col4, #T_6c321_row14_col5 {
#   background-color: black;
#   color: green;
# }
# #T_6c321_row24_col4, #T_6c321_row24_col5 {
#   background-color: black;
#   color: red;
# }
# </style>
# <table id="T_6c321">
#   <thead>
#     <tr>
# ...

# %%
ttest_related_ride_metrics(
    "/workspaces/master-diploma/scripts/resources/rt_benchmark_30.json",
    "/workspaces/master-diploma/scripts/resources/rt_benchmark_30_kalman.json",
    alternative="greater",
)
# Out:
# <style type="text/css">
# #T_94f2c_row4_col0, #T_94f2c_row4_col1, #T_94f2c_row4_col2, #T_94f2c_row4_col3, #T_94f2c_row4_col5, #T_94f2c_row9_col0, #T_94f2c_row9_col2, #T_94f2c_row14_col0, #T_94f2c_row14_col3, #T_94f2c_row14_col4, #T_94f2c_row14_col5, #T_94f2c_row19_col0, #T_94f2c_row19_col1, #T_94f2c_row19_col2, #T_94f2c_row19_col3, #T_94f2c_row19_col4, #T_94f2c_row19_col5, #T_94f2c_row24_col0, #T_94f2c_row24_col2, #T_94f2c_row24_col3, #T_94f2c_row24_col4, #T_94f2c_row29_col0, #T_94f2c_row29_col1, #T_94f2c_row29_col2, #T_94f2c_row29_col3, #T_94f2c_row29_col4, #T_94f2c_row29_col5 {
#   background-color: black;
# }
# #T_94f2c_row4_col4, #T_94f2c_row9_col1, #T_94f2c_row9_col3, #T_94f2c_row9_col4, #T_94f2c_row9_col5, #T_94f2c_row14_col1, #T_94f2c_row14_col2 {
#   background-color: black;
#   color: green;
# }
# #T_94f2c_row24_col1, #T_94f2c_row24_col5 {
#   background-color: black;
#   color: red;
# }
# </style>
# <table id="T_94f2c">
#   <thead>
#     <tr>
# ...

# %%
ttest_related_ride_metrics(
    "/workspaces/master-diploma/scripts/resources/rt_benchmark_30_truck_offset.json",
    "/workspaces/master-diploma/scripts/resources/rt_benchmark_30_truck_offset_kalman.json",
    alternative="greater",
)
# Out:
# <style type="text/css">
# #T_7b6ef_row4_col0, #T_7b6ef_row14_col0, #T_7b6ef_row19_col4, #T_7b6ef_row24_col3, #T_7b6ef_row24_col4 {
#   background-color: black;
#   color: red;
# }
# #T_7b6ef_row4_col1, #T_7b6ef_row4_col2, #T_7b6ef_row4_col3, #T_7b6ef_row4_col4, #T_7b6ef_row4_col5, #T_7b6ef_row9_col1, #T_7b6ef_row9_col3, #T_7b6ef_row9_col4, #T_7b6ef_row9_col5, #T_7b6ef_row14_col1, #T_7b6ef_row14_col2, #T_7b6ef_row14_col3, #T_7b6ef_row14_col5, #T_7b6ef_row29_col0 {
#   background-color: black;
#   color: green;
# }
# #T_7b6ef_row9_col0, #T_7b6ef_row9_col2, #T_7b6ef_row14_col4, #T_7b6ef_row19_col0, #T_7b6ef_row19_col1, #T_7b6ef_row19_col2, #T_7b6ef_row19_col3, #T_7b6ef_row19_col5, #T_7b6ef_row24_col0, #T_7b6ef_row24_col1, #T_7b6ef_row24_col2, #T_7b6ef_row24_col5, #T_7b6ef_row29_col1, #T_7b6ef_row29_col2, #T_7b6ef_row29_col3, #T_7b6ef_row29_col4, #T_7b6ef_row29_col5 {
#   background-color: black;
# }
# </style>
# <table id="T_7b6ef">
#   <thead>
#     <tr>
# ...
